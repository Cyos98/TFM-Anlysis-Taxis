# %% [markdown]
# # Previo

# %%
import pandas as pd
import os

#Ruta directorio principal
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
#Ruta Bases de datos
BRONZE = os.path.abspath(os.path.join(ROOT_DIR, "Datasets", "Bronze"))
SILVER = os.path.abspath(os.path.join(ROOT_DIR, "Datasets", "Silver"))
GOLD = os.path.abspath(os.path.join(ROOT_DIR, "Datasets", "Gold"))

#Fecha del fichero
ano = 2025
mes = 11

#Ficheros
yellow = f"yellow_tripdata_{ano}-{mes:02d}.parquet"
green  = f"green_tripdata_{ano}-{mes:02d}.parquet"
fhv    = f"fhv_tripdata_{ano}-{mes:02d}.parquet"
fhvhv  = f"fhvhv_tripdata_{ano}-{mes:02d}.parquet"

# %% [markdown]
# # Yellow

# %%
Yellow  = pd.read_parquet(BRONZE + "/" + yellow)
Yellow
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               7  2025-11-01 00:13:25   2025-11-01 00:13:25              1.0
# 1               2  2025-11-01 00:49:07   2025-11-01 01:01:22              1.0
# 2               1  2025-11-01 00:07:19   2025-11-01 00:20:41              0.0
# 3               2  2025-11-01 00:00:00   2025-11-01 01:01:03              3.0
# 4               1  2025-11-01 00:18:50   2025-11-01 00:49:32              0.0
# ...           ...                  ...                   ...              ...
# 4181439         2  2025-11-30 23:12:44   2025-11-30 23:43:26              NaN
# 4181440         1  2025-11-30 23:10:35   2025-11-30 23:28:24              NaN
# 4181441         2  2025-11-30 23:09:43   2025-11-30 23:36:08              NaN
# 4181442         1  2025-11-30 23:29:41   2025-11-30 23:47:09              NaN
# 4181443         2  2025-11-30 23:59:06   2025-12-01 00:12:18              NaN
#
# ...

# %%
print(Yellow.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee'],
#       dtype='object')

# %%
Yellow.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         7  2025-11-01 00:13:25   2025-11-01 00:13:25              1.0
# 1         2  2025-11-01 00:49:07   2025-11-01 01:01:22              1.0
# 2         1  2025-11-01 00:07:19   2025-11-01 00:20:41              0.0
# 3         2  2025-11-01 00:00:00   2025-11-01 01:01:03              3.0
# 4         1  2025-11-01 00:18:50   2025-11-01 00:49:32              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.68         1.0                  N            43           186
# 1           2.28         1.0                  N           142           237
# 2           2.70         1.0                  N           163           238
# 3          12.87         1.0                  N           138           261
# 4           8.40         1.0                  N           138            37
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
Yellow.describe()
# Out:
#            VendorID           tpep_pickup_datetime  \
# count  4.181444e+06                        4181444
# mean   1.879423e+00  2025-11-15 10:46:58.380461824
# min    1.000000e+00            2008-12-31 23:04:21
# 25%    2.000000e+00  2025-11-08 00:02:02.750000128
# 50%    2.000000e+00            2025-11-15 10:54:55
# 75%    2.000000e+00  2025-11-22 11:27:26.249999872
# max    7.000000e+00            2025-11-30 23:59:59
# std    7.463690e-01                            NaN
#
#                tpep_dropoff_datetime  passenger_count  trip_distance  \
# count                        4181444     3.166704e+06   4.181444e+06
# mean   2025-11-15 11:05:20.075879168     1.287101e+00   6.530914e+00
# min              2008-12-31 23:32:25     0.000000e+00   0.000000e+00
# 25%    2025-11-08 00:17:31.750000128     1.000000e+00   1.050000e+00
# 50%       2025-11-15 11:08:58.500000     1.000000e+00   1.890000e+00
# 75%    2025-11-22 11:42:58.249999872     1.000000e+00   3.840000e+00
# ...

# %%
#Nulos
(Yellow.isna().mean() * 100).sort_values(ascending=False)
# Out:
# 0

# %%
#duplicados
Yellow.duplicated().sum()

# %% [markdown]
# # Green

# %%
Green  = pd.read_parquet(BRONZE + "/" + green)
Green
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1             2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2             2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3             2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4             1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
# ...         ...                  ...                   ...                ...
# 46907         2  2025-11-30 19:58:34   2025-11-30 20:14:28               None
# 46908         2  2025-11-30 19:34:00   2025-11-30 19:46:00               None
# 46909         2  2025-11-30 21:46:46   2025-11-30 22:17:55               None
# 46910         2  2025-11-30 21:00:00   2025-11-30 21:15:00               None
# 46911         2  2025-11-30 23:26:00   2025-11-30 23:42:00               None
#
# ...

# %% [markdown]
# # FVH

# %%
FHV  = pd.read_parquet(BRONZE + "/" + fhv)
FHV
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 FHV  = pd.read_parquet(BRONZE + "/" + fhv)
#       2 FHV
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parquet.py:509, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     506     use_nullable_dtypes = False
#     507 check_dtype_backend(dtype_backend)
# --> 509 return impl.read(
#     510     path,
#     511     columns=columns,
#     512     storage_options=storage_options,
#     513     use_nullable_dtypes=use_nullable_dtypes,
#     514     dtype_backend=dtype_backend,
#     515     **kwargs,
#     516 )
#
# ...

# %% [markdown]
# # FVHVH

# %%
FHVHV  = pd.read_parquet(BRONZE + "/" + fhvhv)
FHVHV
# Out:
#          hvfhs_license_num dispatching_base_num originating_base_num  \
# 0                   HV0003               B03404               B03404
# 1                   HV0003               B03404               B03404
# 2                   HV0003               B03404               B03404
# 3                   HV0003               B03404               B03404
# 4                   HV0003               B03404               B03404
# ...                    ...                  ...                  ...
# 20818235            HV0003               B03404               B03404
# 20818236            HV0005               B03406                 None
# 20818237            HV0005               B03406                 None
# 20818238            HV0003               B03404               B03404
# 20818239            HV0003               B03404               B03404
#
#             request_datetime   on_scene_datetime     pickup_datetime  \
# ...

# %% [markdown]
# # PCA
